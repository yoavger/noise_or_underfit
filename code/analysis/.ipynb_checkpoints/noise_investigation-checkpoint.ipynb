# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
m = ['mf','mb','habit','wsls']

dfp = []
for model in m:
    df = pd.read_csv(f'../../results/{model}/{model}_parameters.csv')
    df.drop(columns=['Unnamed: 0'],inplace=True)
    dfp.append(df)

df_true_param = pd.read_csv('../../results/kdh/kdh_parameters.csv')

param = {'p_0':[],
        'p_1':[]
        }

for i,p in enumerate (df_true_param['p_dh']):
    p = p.replace('[','')
    p = p.replace(']','')
    p = p.replace('  ',' ')
    indices = [z for z, w in enumerate(p) if w == '.']
    x_0 = p[(indices[0]-1):(indices[1]-2)]
    x_1 = p[(indices[1]-1):]
    x_0=float(x_0[:-1])
    x_1=float(x_1[:-1])
        
    param['p_0'].append(x_0)
    param['p_1'].append(x_1)
    
dfp.append(pd.DataFrame(param))

noise_mf=1-(dfp[0]['beta']-dfp[0]['beta'].min())/(dfp[0]['beta'].max()-dfp[0]['beta'].min())
noise_mb=1-(dfp[1]['beta']-dfp[1]['beta'].min())/(dfp[1]['beta'].max()-dfp[1]['beta'].min())
noise_h=1-(dfp[2]['beta']-dfp[2]['beta'].min())/(dfp[2]['beta'].max()-dfp[2]['beta'].min())

a = np.absolute(dfp[3]['p_stay_win'] -.5)
b = np.absolute(dfp[3]['p_shift_lose'] -.5)
ab = a*b 
noise_wsls = 1-(ab-ab.min())/(ab.max()-ab.min())

a = np.absolute(dfp[4]['p_0'] -.5)
b = np.absolute(dfp[4]['p_1'] -.5)
ab = a*b 
noise_kdh = 1-(ab-ab.min())/(ab.max()-ab.min())

df_noise = pd.DataFrame({
                        'noise_mf':noise_mf,
                        'noise_mb':noise_mb,
                        'noise_habit':noise_h,
                        'noise_wsls':noise_wsls,
                        'noise_kdh':noise_kdh}
                        )
df_nlp = pd.read_csv('all_model_nlp.csv')

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(24, 5))
gs = fig.add_gridspec(1,5, hspace=0, wspace=0.05 )
axes = gs.subplots(sharey=True)
models = {
        'mf':[sns.color_palette("tab10")[0],'Model-Free'],
        'mb':[sns.color_palette("tab10")[1],'Model-Based'],
        'habit':[sns.color_palette("tab10")[2],'Habit'],
        'wsls':[sns.color_palette("tab10")[3],'Win Stay, Lose Shift'],
        'kdh':[sns.color_palette("tab10" )[4],'k-Dominant Hand'],
}
for i,m in enumerate(models):
    data = (df_nlp.iloc[i*100:i*100+100]).reset_index()
    y_0 = data[f'test_nlp_{m}'] - data['best_test_nlp_rnn']
    y_1 = data[f'test_nlp_{m}'] - data['test_nlp_logistic_regression']
    sns.scatterplot(ax=axes[i],x=df_noise[f'noise_{m}'],y=data[f'test_nlp_{m}'],color=models[m][0],label=models[m][1])
    sns.scatterplot(ax=axes[i],x=df_noise[f'noise_{m}'],y=data['best_test_nlp_rnn'],label='RNN',color='gold')
    if i !=3:
        sns.scatterplot(ax=axes[i],x=df_noise[f'noise_{m}'],y=data['test_nlp_logistic_regression'],label='LR',color='silver')
    
    axes[i].set_xlabel('',size=12)
    axes[i].set_ylabel('')
    axes[i].legend(loc='lower left',fontsize=12)

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(24, 5))
gs = fig.add_gridspec(1,5, hspace=0, wspace=0.05 )
axes = gs.subplots(sharey=True)
models = {
        'mf':[sns.color_palette("tab10")[0],'Model-Free'],
        'mb':[sns.color_palette("tab10")[1],'Model-Based'],
        'habit':[sns.color_palette("tab10")[2],'Habit'],
        'wsls':[sns.color_palette("tab10")[3],'Win Stay, Lose Shift'],
        'kdh':[sns.color_palette("tab10" )[4],'k-Dominant Hand'],
}
for i,m in enumerate(models):
    data = (df_nlp.iloc[i*100:i*100+100]).reset_index()
    y_0 = data[f'test_nlp_{m}'] - data['best_test_nlp_rnn']
    y_1 = data[f'test_nlp_{m}'] - data[f'test_nlp_{m}']
    sns.lineplot(ax=axes[i],x=[0,1],y=[0,0],color='black')    
    sns.scatterplot(ax=axes[i],x=df_noise[f'noise_{m}'],y=y_0,color=models[m][0],label=f'{models[m][1]}-RNN')
    axes[i].set_xlabel('',size=12)
    axes[i].set_ylabel('')
    axes[i].legend(loc='lower left',fontsize=12)

# %%
mf = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]


low_0.loc[ (low_0['model'] == 'mf') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_mf'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'mf') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_mf'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'mf') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_mf'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'mf') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_mf'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_mf = np.array(mf)

mb = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]


low_0.loc[ (low_0['model'] == 'mb') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_mb'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'mb') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_mb'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'mb') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_mb'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'mb') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_mb'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_mb = np.array(mb)

habit = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]

low_0.loc[ (low_0['model'] == 'habit') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_habit'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'habit') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_habit'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'habit') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_habit'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'habit') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_habit'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_habit = np.array(habit)

wsls = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]

low_0.loc[ (low_0['model'] == 'wsls') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_wsls'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'wsls') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_wsls'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'wsls') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_wsls'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'wsls') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_wsls'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_wsls = np.array(wsls)

kdh = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]

low_0.loc[ (low_0['model'] == 'kdh') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_kdh'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'kdh') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_kdh'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'kdh') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_kdh'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'kdh') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_kdh'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_kdh = np.array(kdh)

sns.set_style("whitegrid")
plt.figure(figsize=(8,6))
plt.plot(acc_mf)
plt.scatter([0,1,2,3],acc_mf)
plt.plot(acc_mb)
plt.scatter([0,1,2,3],acc_mb)
plt.plot(acc_habit)
plt.scatter([0,1,2,3],acc_habit)
plt.plot(acc_wsls)
plt.scatter([0,1,2,3],acc_wsls)
plt.plot(acc_kdh)
plt.scatter([0,1,2,3],acc_kdh)
plt.xticks([0,1,2,3])
plt.ylabel('Accuracy',size=14)
plt.xlabel('Noise',size=14)
plt.legend(['Model-Free','Model-Based','Habit','WSLS','K-DH'],fontsize=12,loc='lower left')

mf = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]


low_0.loc[ (low_0['model'] == 'mf') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_mf'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'mf') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_mf'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'mf') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_mf'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'mf') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'mf') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_mf'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
mf.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_mf = np.array(mf)

mb = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]


low_0.loc[ (low_0['model'] == 'mb') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_mb'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'mb') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_mb'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'mb') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_mb'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'mb') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'mb') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_mb'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
mb.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_mb = np.array(mb)

habit = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]

low_0.loc[ (low_0['model'] == 'habit') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_habit'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'habit') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_habit'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'habit') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_habit'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'habit') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'habit') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_habit'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
habit.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_habit = np.array(habit)

wsls = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]

low_0.loc[ (low_0['model'] == 'wsls') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_wsls'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'wsls') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_wsls'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'wsls') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_wsls'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'wsls') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'wsls') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_wsls'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
wsls.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_wsls = np.array(wsls)

kdh = []
from sklearn.metrics import accuracy_score
df_nlp['noise'] = ((df_noise.values).T).flatten()
df_nlp['noise_low_high'] = pd.cut(df_nlp['noise'], bins=4,labels=['0','1','2','3'])
low_0 = df_nlp[(df_nlp['noise_low_high'] == '0') ]
low_1 = df_nlp[(df_nlp['noise_low_high'] == '1') ]
low_2 = df_nlp[(df_nlp['noise_low_high'] == '2') ]
low_3 = df_nlp[(df_nlp['noise_low_high'] == '3') ]

low_0.loc[ (low_0['model'] == 'kdh') ,'label'] = 0
low_0.loc[ (low_0['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_0[f'test_nlp_kdh'] - low_0[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_0['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_1.loc[ (low_1['model'] == 'kdh') ,'label'] = 0
low_1.loc[ (low_1['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_1[f'test_nlp_kdh'] - low_1[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_1['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))

low_2.loc[ (low_2['model'] == 'kdh') ,'label'] = 0
low_2.loc[ (low_2['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_2[f'test_nlp_kdh'] - low_2[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_2['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))


low_3.loc[ (low_3['model'] == 'kdh') ,'label'] = 0
low_3.loc[ (low_3['model'] != 'kdh') ,'label'] = 1
y_pred = (np.array(low_3[f'test_nlp_kdh'] - low_3[f'test_nlp_logistic_regression']) > 0).astype(int)
y_true = np.array(low_3['label'])
kdh.append(accuracy_score(y_true=y_true,y_pred=y_pred))

acc_kdh = np.array(kdh)

sns.set_style("whitegrid")
plt.figure(figsize=(8,6))
plt.plot(acc_mf)
plt.scatter([0,1,2,3],acc_mf)
plt.plot(acc_mb)
plt.scatter([0,1,2,3],acc_mb)
plt.plot(acc_habit)
plt.scatter([0,1,2,3],acc_habit)
plt.plot(acc_wsls)
plt.scatter([0,1,2,3],acc_wsls)
plt.plot(acc_kdh)
plt.scatter([0,1,2,3],acc_kdh)
plt.xticks([0,1,2,3])
plt.ylabel('Accuracy',size=14)
plt.xlabel('Noise',size=14)
plt.legend(['Model-Free','Model-Based','Habit','WSLS','K-DH'],fontsize=12,loc='lower left')
